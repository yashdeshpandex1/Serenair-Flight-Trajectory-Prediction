# %%
from engine import training_loop

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 407.78 meters
# Epoch 1 | New Best Val Loss: 375.84 meters
# 2026/06/23 20:36:25 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# ...

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 training_loop(model_class='LSTMModelV2', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:153, in training_loop(model_class, num_epochs, train_loss_fn, eval_loss_fn, optimize, learning_rate, wd, num_layers, batch_size, hidden_size, task)
#     146 def training_loop(model_class, num_epochs=10,
#     147                   train_loss_fn=nn.HuberLoss, eval_loss_fn=HaversineLoss,
#     148                   optimize=torch.optim.Adam, learning_rate=0.001, wd=0.0,
#     149                   num_layers=2, batch_size=64, hidden_size=64,
#     150                   task='next_instance'):
# ...

# %%
training_loop(model_class='GRUV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='BidirectionalLSTMV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='HybridConvLSTMV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='HybridConvLSTMV3', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='HybridConvLSTMBidirectional', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='AttentionModel', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='HybridConvAttentionGRUModel', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='Seq2SeqLSTMV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='Seq2SeqLSTMV2', num_epochs=100, batch_size=128, wd=1e-5, task='next_instance')

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='GRUV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='BidirectionalLSTMV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMV3', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMBidirectional', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='AttentionModel', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvAttentionGRUModel', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='Seq2SeqLSTMV1', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')

# %%
training_loop(model_class='Seq2SeqLSTMV2', num_epochs=100, batch_size=128, wd=1e-5, task='next_ten_mins')
