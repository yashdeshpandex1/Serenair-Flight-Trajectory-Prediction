# %% [markdown]
# # LSTMModelv1

# %%
from engine import training_loop
import torch

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 391.73 meters
# Epoch 1 | New Best Val Loss: 367.32 meters
# Epoch 2 | New Best Val Loss: 361.49 meters
# Epoch 3 | New Best Val Loss: 355.33 meters
# Epoch 6 | New Best Val Loss: 349.34 meters
# Epoch 7 | New Best Val Loss: 343.26 meters
# Epoch 9 | New Best Val Loss: 342.75 meters
# Epoch 12 | New Best Val Loss: 339.72 meters
# Epoch 16 | New Best Val Loss: 336.66 meters
# Epoch 20 | New Best Val Loss: 335.79 meters
# Epoch 22 | New Best Val Loss: 335.63 meters
# Epoch 26 | New Best Val Loss: 335.47 meters
# Epoch 28 | New Best Val Loss: 332.12 meters
# Epoch 35 | New Best Val Loss: 327.44 meters
# Epoch 37 | New Best Val Loss: 325.56 meters
# Epoch 45 | New Best Val Loss: 322.03 meters
# Epoch 52 | New Best Val Loss: 319.28 meters
# Run complete. LSTMModelV1 saved securely to MLflow.
# 🏃 View run LSTMModelV1 at: https://centralindia.api.azureml.ms/mlflow/v2.0/subscriptions/9c6d92fe-6e3c-4c70-902a-807ab9d2d1eb/resourceGroups/serenair_rg/providers/Microsoft.MachineLearningServices/workspaces/serenair/#/experiments/89eb4355-7399-4b60-bbaf-fd4d881d7b87/runs/87a77cba-fe6e-41d8-aa46-d8859b3cdaa3
# 🧪 View experiment at: https://centralindia.api.azureml.ms/mlflow/v2.0/subscriptions/9c6d92fe-6e3c-4c70-902a-807ab9d2d1eb/resourceGroups/serenair_rg/providers/Microsoft.MachineLearningServices/workspaces/serenair/#/experiments/89eb4355-7399-4b60-bbaf-fd4d881d7b87

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV2
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 400.14 meters
# Epoch 1 | New Best Val Loss: 383.05 meters
# Epoch 2 | New Best Val Loss: 375.21 meters
# Epoch 3 | New Best Val Loss: 362.87 meters
# Epoch 4 | New Best Val Loss: 356.57 meters
# Epoch 9 | New Best Val Loss: 349.92 meters
# Epoch 11 | New Best Val Loss: 346.74 meters
# Epoch 18 | New Best Val Loss: 335.69 meters
# Epoch 22 | New Best Val Loss: 335.22 meters
# Epoch 24 | New Best Val Loss: 332.96 meters
# Epoch 31 | New Best Val Loss: 331.39 meters
# Epoch 32 | New Best Val Loss: 329.06 meters
# Epoch 40 | New Best Val Loss: 328.28 meters
# Epoch 47 | New Best Val Loss: 327.02 meters
# Epoch 49 | New Best Val Loss: 326.66 meters
# Epoch 52 | New Best Val Loss: 325.16 meters
# Epoch 55 | New Best Val Loss: 324.56 meters
# Epoch 67 | New Best Val Loss: 324.28 meters
# Run complete. LSTMModelV2 saved securely to MLflow.
# 🏃 View run LSTMModelV2 at: https://centralindia.api.azureml.ms/mlflow/v2.0/subscriptions/9c6d92fe-6e3c-4c70-902a-807ab9d2d1eb/resourceGroups/serenair_rg/providers/Microsoft.MachineLearningServices/workspaces/serenair/#/experiments/89eb4355-7399-4b60-bbaf-fd4d881d7b87/runs/42a1923e-0968-4a37-981f-2a0239965aa6
# 🧪 View experiment at: https://centralindia.api.azureml.ms/mlflow/v2.0/subscriptions/9c6d92fe-6e3c-4c70-902a-807ab9d2d1eb/resourceGroups/serenair_rg/providers/Microsoft.MachineLearningServices/workspaces/serenair/#/experiments/89eb4355-7399-4b60-bbaf-fd4d881d7b87

# %%
training_loop(model_class='GRUV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking GRUV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 378.06 meters
# Epoch 2 | New Best Val Loss: 364.08 meters
# Epoch 3 | New Best Val Loss: 363.47 meters
# Epoch 4 | New Best Val Loss: 359.35 meters
# Epoch 5 | New Best Val Loss: 358.55 meters
# Epoch 7 | New Best Val Loss: 351.06 meters
# Epoch 8 | New Best Val Loss: 348.91 meters
# Epoch 11 | New Best Val Loss: 348.33 meters
# Epoch 18 | New Best Val Loss: 341.76 meters
# Epoch 24 | New Best Val Loss: 339.61 meters
# Epoch 26 | New Best Val Loss: 338.54 meters
# Epoch 27 | New Best Val Loss: 331.31 meters
# Epoch 40 | New Best Val Loss: 328.05 meters
# Epoch 47 | New Best Val Loss: 326.37 meters
# Epoch 60 | New Best Val Loss: 324.90 meters
# Run complete. GRUV1 saved securely to MLflow.
# 🏃 View run GRUV1 at: https://centralindia.api.azureml.ms/mlflow/v2.0/subscriptions/9c6d92fe-6e3c-4c70-902a-807ab9d2d1eb/resourceGroups/serenair_rg/providers/Microsoft.MachineLearningServices/workspaces/serenair/#/experiments/89eb4355-7399-4b60-bbaf-fd4d881d7b87/runs/cbf355ff-bd18-4b27-af86-8f2d36bc6c0a
# 🧪 View experiment at: https://centralindia.api.azureml.ms/mlflow/v2.0/subscriptions/9c6d92fe-6e3c-4c70-902a-807ab9d2d1eb/resourceGroups/serenair_rg/providers/Microsoft.MachineLearningServices/workspaces/serenair/#/experiments/89eb4355-7399-4b60-bbaf-fd4d881d7b87

# %%
training_loop(model_class='BidirectionalLSTMV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 training_loop(model_class='BidirectionalLSTMModelV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:156, in training_loop(model_class, num_epochs, train_loss_fn, eval_loss_fn, optimize, learning_rate, wd, num_layers, batch_size, hidden_size, task)
#     154     target_mean = target_mean.to(device)
#     155     target_scale = target_scale.to(device)
# --> 156     model = run_experiment(model_name=model_class, num_layers=num_layers,
#     157                            hidden_size=hidden_size, task=task)
#     158 elif task == 'next_ten_mins':
#     159     setup_mlflow(task=task)
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\run_experiment.py:36, in run_experiment(model_name, hidden_size, num_layers, task)
#      33 device = 'cuda' if torch.cuda.is_available() else 'cpu'
#      35 if task == 'next_instance':
# ---> 36     model_class = MODEL_REGISTRY[model_name]
#      37     model = model_class(input_size=21, hidden_size=hidden_size,
#      38                         num_layers=num_layers, output_size=2).to(device)
#      39 elif task == 'next_ten_mins':
#
# KeyError: 'BidirectionalLSTMModelV1'

# %%
training_loop(model_class='HybridConvLSTMV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')

# %%
training_loop(model_class='HybridConvLSTMV3', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')

# %%
training_loop(model_class='HybridConvLSTMBidirectional', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')

# %%
training_loop(model_class='AttentionModel', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')

# %%
training_loop(model_class='HybridConvAttentionGRUModel', num_epochs=100, wd=1e-5, batch_size=128, task='next_instance')

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='GRUV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking GRUV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 1087.65 meters
# Epoch 1 | New Best Val Loss: 1084.96 meters
# Epoch 2 | New Best Val Loss: 1077.47 meters
# Epoch 3 | New Best Val Loss: 1040.17 meters
# Epoch 4 | New Best Val Loss: 980.19 meters
# Epoch 5 | New Best Val Loss: 921.18 meters
# Epoch 6 | New Best Val Loss: 877.12 meters
# Epoch 7 | New Best Val Loss: 856.94 meters
# Epoch 8 | New Best Val Loss: 841.31 meters
# Epoch 9 | New Best Val Loss: 831.59 meters
# Epoch 10 | New Best Val Loss: 830.16 meters
# Epoch 11 | New Best Val Loss: 826.38 meters
# Epoch 13 | New Best Val Loss: 822.19 meters
# Epoch 14 | New Best Val Loss: 820.25 meters
# Epoch 17 | New Best Val Loss: 814.73 meters

# %%
training_loop(model_class='BidirectionalLSTMV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMV3', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvLSTMBidirectional', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='AttentionModel', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='HybridConvAttentionGRUModel', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='Seq2SeqLSTMV1', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')

# %%
training_loop(model_class='Seq2SeqLSTMV2', num_epochs=100, wd=1e-5, batch_size=128, task='next_ten_mins')
