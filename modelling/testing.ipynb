# %%
from engine import training_loop

# %%
training_loop()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:58: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=1.0)
# Epoch [1/10] | Train Loss: nan meters | Test Loss: nan meters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 training_loop()
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:44, in training_loop(num_epochs, loss_fn, optimize, learning_rate, wd)
#      41 train_loss = 0.0
#      43 # Unpack batch_X, batch_y, batch_anchor and send to 'device' batch-wise
# ---> 44 for batch_X, batch_y, batch_anchor in train_loader:
#      45     batch_X = batch_X.to(device)
# ...
