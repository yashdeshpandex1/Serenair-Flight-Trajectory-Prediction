# %% [markdown]
# # LSTMModelv1

# %%
from engine import training_loop
import torch

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-5, num_layers=1)
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 541.47 meters
# Epoch 1 | New Best Val Loss: 447.96 meters
# Epoch 2 | New Best Val Loss: 444.18 meters
# Epoch 3 | New Best Val Loss: 432.82 meters
# Epoch 5 | New Best Val Loss: 421.33 meters
# Epoch 6 | New Best Val Loss: 412.70 meters
# Epoch 7 | New Best Val Loss: 404.76 meters
# Epoch 14 | New Best Val Loss: 392.47 meters
# Epoch 15 | New Best Val Loss: 390.49 meters
# Epoch 17 | New Best Val Loss: 387.71 meters
# Epoch 26 | New Best Val Loss: 384.89 meters
# Epoch 31 | New Best Val Loss: 383.98 meters
# Epoch 35 | New Best Val Loss: 383.94 meters
# Epoch 36 | New Best Val Loss: 380.58 meters
# Epoch 44 | New Best Val Loss: 380.36 meters
# Epoch 46 | New Best Val Loss: 379.57 meters
# Epoch 51 | New Best Val Loss: 379.30 meters
# Epoch 60 | New Best Val Loss: 376.32 meters
# ...

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-5, num_layers=2)
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 449.84 meters
# Epoch 1 | New Best Val Loss: 423.91 meters
# Epoch 2 | New Best Val Loss: 422.14 meters
# Epoch 3 | New Best Val Loss: 414.04 meters
# Epoch 4 | New Best Val Loss: 411.21 meters
# Epoch 5 | New Best Val Loss: 410.83 meters
# Epoch 8 | New Best Val Loss: 402.51 meters
# Epoch 15 | New Best Val Loss: 387.69 meters
# Epoch 16 | New Best Val Loss: 385.96 meters
# Epoch 23 | New Best Val Loss: 379.75 meters
# Epoch 27 | New Best Val Loss: 379.50 meters
# Epoch 28 | New Best Val Loss: 379.17 meters
# Epoch 29 | New Best Val Loss: 377.55 meters
# Epoch 32 | New Best Val Loss: 377.15 meters
# Epoch 39 | New Best Val Loss: 376.11 meters
# Epoch 40 | New Best Val Loss: 372.79 meters
# Epoch 43 | New Best Val Loss: 372.05 meters
# Epoch 54 | New Best Val Loss: 371.56 meters
# ...

# %% [markdown]
# ---

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, wd=1e-5, num_layers=2, batch_size=512)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV2
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 782.04 meters
# Epoch 1 | New Best Val Loss: 593.05 meters
# Epoch 2 | New Best Val Loss: 489.03 meters
# Epoch 3 | New Best Val Loss: 480.15 meters
# Epoch 4 | New Best Val Loss: 442.43 meters
# Epoch 7 | New Best Val Loss: 433.91 meters
# Epoch 8 | New Best Val Loss: 416.92 meters
# Epoch 15 | New Best Val Loss: 404.32 meters
# ...

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, wd=1e-5, num_layers=2, batch_size=256)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV2
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, wd=1e-5, num_layers=2, batch_size=128)

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, wd=1e-5, num_layers=2, batch_size=64)

# %%
training_loop(model_class='GRUV1', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking GRUV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 848.74 meters
# Epoch 1 | New Best Val Loss: 808.19 meters
# Epoch 2 | New Best Val Loss: 762.43 meters
# Epoch 3 | New Best Val Loss: 679.46 meters
# Epoch 4 | New Best Val Loss: 570.27 meters
# Epoch 5 | New Best Val Loss: 525.06 meters
# Epoch 6 | New Best Val Loss: 473.80 meters
# Epoch 8 | New Best Val Loss: 462.14 meters
# ...

# %%
training_loop(model_class='BidirectionalLSTMV1', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking BidirectionalLSTMV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 853.10 meters
# Epoch 1 | New Best Val Loss: 803.03 meters
# Epoch 2 | New Best Val Loss: 775.69 meters
# Epoch 3 | New Best Val Loss: 698.39 meters
# Epoch 4 | New Best Val Loss: 567.52 meters
# Epoch 5 | New Best Val Loss: 483.53 meters
# Epoch 6 | New Best Val Loss: 463.49 meters
# Epoch 9 | New Best Val Loss: 459.60 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMV1', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 861.65 meters
# Epoch 1 | New Best Val Loss: 824.95 meters
# Epoch 2 | New Best Val Loss: 806.81 meters
# Epoch 3 | New Best Val Loss: 788.77 meters
# Epoch 4 | New Best Val Loss: 697.29 meters
# Epoch 5 | New Best Val Loss: 572.65 meters
# Epoch 6 | New Best Val Loss: 517.71 meters
# Epoch 7 | New Best Val Loss: 497.45 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV2
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 869.62 meters
# Epoch 1 | New Best Val Loss: 821.79 meters
# Epoch 2 | New Best Val Loss: 792.80 meters
# Epoch 3 | New Best Val Loss: 743.68 meters
# Epoch 4 | New Best Val Loss: 608.93 meters
# Epoch 5 | New Best Val Loss: 517.98 meters
# Epoch 6 | New Best Val Loss: 504.58 meters
# Epoch 7 | New Best Val Loss: 471.59 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMV3', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV3
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 865.64 meters
# Epoch 1 | New Best Val Loss: 828.23 meters
# Epoch 2 | New Best Val Loss: 792.98 meters
# Epoch 3 | New Best Val Loss: 726.84 meters
# Epoch 4 | New Best Val Loss: 631.12 meters
# Epoch 5 | New Best Val Loss: 549.63 meters
# Epoch 6 | New Best Val Loss: 515.76 meters
# Epoch 7 | New Best Val Loss: 500.61 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMBidirectional', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMBidirectional
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 826.07 meters
# Epoch 1 | New Best Val Loss: 787.77 meters
# Epoch 2 | New Best Val Loss: 736.29 meters
# Epoch 3 | New Best Val Loss: 560.34 meters
# Epoch 4 | New Best Val Loss: 513.59 meters
# Epoch 5 | New Best Val Loss: 485.59 meters
# Epoch 6 | New Best Val Loss: 476.74 meters
# Epoch 7 | New Best Val Loss: 463.90 meters
# ...

# %%
training_loop(model_class='lstmv2')

# %%
training_loop(model_class='AttentionModel', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 training_loop(model_class='AttentionModel', num_epochs=100, wd=1e-5)
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:87, in training_loop(model_class, num_epochs, train_loss_fn, eval_loss_fn, optimize, learning_rate, wd)
# ...

# %%
training_loop(model_class='HybridConvAttentionGRUModel', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvAttentionGRUModel
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 863.58 meters
# Epoch 1 | New Best Val Loss: 813.21 meters
# Epoch 2 | New Best Val Loss: 777.28 meters
# Epoch 3 | New Best Val Loss: 756.26 meters
# Epoch 4 | New Best Val Loss: 674.65 meters
# Epoch 5 | New Best Val Loss: 570.69 meters
# Epoch 6 | New Best Val Loss: 516.37 meters
# Epoch 7 | New Best Val Loss: 496.52 meters
# ...
