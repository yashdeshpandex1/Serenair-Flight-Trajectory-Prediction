# %% [markdown]
# # LSTMModelv1

# %%
from engine import training_loop
import torch

# %% [markdown]
# ---

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-5, batch_size=64)
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 378.47 meters
# Epoch 1 | New Best Val Loss: 365.14 meters
# Epoch 2 | New Best Val Loss: 357.68 meters
# Epoch 3 | New Best Val Loss: 344.04 meters
# Epoch 7 | New Best Val Loss: 340.40 meters
# Epoch 14 | New Best Val Loss: 336.39 meters
# Epoch 16 | New Best Val Loss: 334.00 meters
# Epoch 17 | New Best Val Loss: 331.40 meters
# Epoch 19 | New Best Val Loss: 329.23 meters
# Epoch 23 | New Best Val Loss: 328.81 meters
# Epoch 31 | New Best Val Loss: 327.68 meters
# Epoch 32 | New Best Val Loss: 326.91 meters
# Epoch 39 | New Best Val Loss: 323.82 meters
# Epoch 40 | New Best Val Loss: 323.62 meters
# Epoch 41 | New Best Val Loss: 321.90 meters

# %%
training_loop(model_class='LSTMModelV2', num_epochs=100, wd=1e-5, batch_size=128, hidden_size=128)

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, wd=1e-5, batch_size=256)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV2
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 641.50 meters
# Epoch 1 | New Best Val Loss: 504.36 meters
# Epoch 2 | New Best Val Loss: 444.80 meters
# Epoch 3 | New Best Val Loss: 438.16 meters
# Epoch 4 | New Best Val Loss: 422.45 meters
# Epoch 6 | New Best Val Loss: 418.57 meters
# Epoch 7 | New Best Val Loss: 417.67 meters
# Epoch 11 | New Best Val Loss: 405.99 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, wd=1e-5, batch_size=128)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV2
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 490.40 meters
# Epoch 1 | New Best Val Loss: 442.41 meters
# Epoch 2 | New Best Val Loss: 435.93 meters
# Epoch 5 | New Best Val Loss: 422.10 meters
# Epoch 8 | New Best Val Loss: 408.86 meters
# Epoch 9 | New Best Val Loss: 402.68 meters
# Epoch 16 | New Best Val Loss: 390.50 meters
# Epoch 23 | New Best Val Loss: 385.75 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, wd=1e-5, batch_size=64)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV2
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 526.68 meters
# Epoch 1 | New Best Val Loss: 473.46 meters
# Epoch 3 | New Best Val Loss: 432.99 meters
# Epoch 5 | New Best Val Loss: 425.48 meters
# Epoch 8 | New Best Val Loss: 421.50 meters
# Epoch 13 | New Best Val Loss: 419.56 meters
# Epoch 20 | New Best Val Loss: 416.61 meters
# Epoch 21 | New Best Val Loss: 415.31 meters
# ...

# %%
from engine import training_loop

# %%
training_loop(model_class='HybridConvLSTMV1', num_epochs=100, wd=1e-5, batch_size=256)
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 651.20 meters
# Epoch 1 | New Best Val Loss: 518.18 meters
# Epoch 2 | New Best Val Loss: 453.83 meters
# Epoch 3 | New Best Val Loss: 439.21 meters
# Epoch 4 | New Best Val Loss: 427.15 meters
# Epoch 7 | New Best Val Loss: 425.09 meters
# Epoch 9 | New Best Val Loss: 423.86 meters
# Epoch 11 | New Best Val Loss: 417.04 meters
# Epoch 12 | New Best Val Loss: 412.66 meters
# Epoch 13 | New Best Val Loss: 406.11 meters
# Epoch 20 | New Best Val Loss: 396.27 meters
# Epoch 21 | New Best Val Loss: 388.78 meters
# Epoch 22 | New Best Val Loss: 387.93 meters
# Epoch 25 | New Best Val Loss: 384.67 meters
# Epoch 32 | New Best Val Loss: 384.48 meters
# Epoch 34 | New Best Val Loss: 383.04 meters
# Epoch 36 | New Best Val Loss: 380.58 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMV1', num_epochs=100, wd=1e-5, batch_size=256, hidden_size=128)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 514.95 meters
# Epoch 1 | New Best Val Loss: 453.04 meters
# Epoch 3 | New Best Val Loss: 441.59 meters
# Epoch 5 | New Best Val Loss: 432.37 meters
# Epoch 6 | New Best Val Loss: 420.44 meters
# Epoch 7 | New Best Val Loss: 416.11 meters
# Epoch 14 | New Best Val Loss: 412.07 meters
# Epoch 15 | New Best Val Loss: 396.68 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMV2', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMV3
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 865.64 meters
# Epoch 1 | New Best Val Loss: 828.23 meters
# Epoch 2 | New Best Val Loss: 792.98 meters
# Epoch 3 | New Best Val Loss: 726.84 meters
# Epoch 4 | New Best Val Loss: 631.12 meters
# Epoch 5 | New Best Val Loss: 549.63 meters
# Epoch 6 | New Best Val Loss: 515.76 meters
# Epoch 7 | New Best Val Loss: 500.61 meters
# ...

# %%
training_loop(model_class='HybridConvLSTMBidirectional', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvLSTMBidirectional
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 826.07 meters
# Epoch 1 | New Best Val Loss: 787.77 meters
# Epoch 2 | New Best Val Loss: 736.29 meters
# Epoch 3 | New Best Val Loss: 560.34 meters
# Epoch 4 | New Best Val Loss: 513.59 meters
# Epoch 5 | New Best Val Loss: 485.59 meters
# Epoch 6 | New Best Val Loss: 476.74 meters
# Epoch 7 | New Best Val Loss: 463.90 meters
# ...

# %%
training_loop(model_class='AttentionModel', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 training_loop(model_class='AttentionModel', num_epochs=100, wd=1e-5)
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:87, in training_loop(model_class, num_epochs, train_loss_fn, eval_loss_fn, optimize, learning_rate, wd)
# ...

# %%
training_loop(model_class='HybridConvAttentionGRUModel', num_epochs=100, wd=1e-5)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking HybridConvAttentionGRUModel
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 863.58 meters
# Epoch 1 | New Best Val Loss: 813.21 meters
# Epoch 2 | New Best Val Loss: 777.28 meters
# Epoch 3 | New Best Val Loss: 756.26 meters
# Epoch 4 | New Best Val Loss: 674.65 meters
# Epoch 5 | New Best Val Loss: 570.69 meters
# Epoch 6 | New Best Val Loss: 516.37 meters
# Epoch 7 | New Best Val Loss: 496.52 meters
# ...
