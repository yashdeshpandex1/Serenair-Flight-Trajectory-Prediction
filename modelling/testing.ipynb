# %% [markdown]
# # LSTMModelv1

# %%
from engine import training_loop
import torch

# %% [markdown]
# ---

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-3, batch_size=256)
# Out:
# Found the config file in: .\config.json
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 623.25 meters
# Epoch 1 | New Best Val Loss: 590.92 meters
# Epoch 2 | New Best Val Loss: 557.26 meters
# Epoch 3 | New Best Val Loss: 545.17 meters
# Epoch 4 | New Best Val Loss: 541.86 meters
# Epoch 6 | New Best Val Loss: 528.08 meters
# Epoch 10 | New Best Val Loss: 523.45 meters
# Epoch 11 | New Best Val Loss: 513.38 meters
# Epoch 18 | New Best Val Loss: 509.03 meters
# Epoch 19 | New Best Val Loss: 503.47 meters
# Epoch 21 | New Best Val Loss: 503.12 meters
# Epoch 28 | New Best Val Loss: 497.87 meters
# Epoch 29 | New Best Val Loss: 497.67 meters
# Epoch 31 | New Best Val Loss: 496.33 meters
# Epoch 36 | New Best Val Loss: 493.21 meters
# Epoch 40 | New Best Val Loss: 489.66 meters
# Epoch 46 | New Best Val Loss: 486.05 meters
# Epoch 48 | New Best Val Loss: 481.64 meters
# ...

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-4, batch_size=256)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 483.46 meters
# Epoch 1 | New Best Val Loss: 407.97 meters
# Epoch 2 | New Best Val Loss: 391.51 meters
# Epoch 5 | New Best Val Loss: 376.51 meters
# Epoch 6 | New Best Val Loss: 373.44 meters
# Epoch 10 | New Best Val Loss: 369.77 meters
# Epoch 16 | New Best Val Loss: 369.02 meters
# Epoch 17 | New Best Val Loss: 368.04 meters
# ...

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-5, batch_size=256)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 412.02 meters
# Epoch 1 | New Best Val Loss: 384.04 meters
# Epoch 2 | New Best Val Loss: 372.23 meters
# Epoch 3 | New Best Val Loss: 364.27 meters
# Epoch 4 | New Best Val Loss: 361.40 meters
# Epoch 5 | New Best Val Loss: 359.13 meters
# Epoch 6 | New Best Val Loss: 350.79 meters
# Epoch 8 | New Best Val Loss: 349.01 meters
# ...

# %%
training_loop(model_class='LSTMModelV1', num_epochs=100, wd=1e-6, batch_size=256)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Connected to azure mlflow server
# Mlflow started tracking LSTMModelV1
# Training Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | New Best Val Loss: 401.63 meters
# Epoch 1 | New Best Val Loss: 385.83 meters
# Epoch 2 | New Best Val Loss: 372.00 meters
# Epoch 3 | New Best Val Loss: 356.39 meters
# Epoch 4 | New Best Val Loss: 349.23 meters
# Epoch 6 | New Best Val Loss: 347.91 meters
# Epoch 7 | New Best Val Loss: 346.73 meters
# Epoch 8 | New Best Val Loss: 336.94 meters
# ...
