# %%
from engine import training_loop

# %%
training_loop()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:58: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=1.0)
# Epoch [1/10] | Train Loss: 4418.39 meters | Test Loss: 4150.64 meters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 training_loop()
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\modelling\engine.py:59, in training_loop(num_epochs, loss_fn, optimize, learning_rate, wd)
#      57 loss.backward()
#      58 torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=1.0)
# ---> 59 optimizer.step()
#      61 # Add to training loss
#      62 train_loss += loss.item()
#
# ...
