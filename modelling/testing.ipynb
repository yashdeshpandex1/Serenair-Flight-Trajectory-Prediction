# %%
from engine import training_loop

# %%
training_loop()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch [1/10] | Train Loss: 1338.79 meters | Test Loss: 874.31 meters
# Epoch [2/10] | Train Loss: 1260.66 meters | Test Loss: 829.18 meters
# Epoch [3/10] | Train Loss: 1216.29 meters | Test Loss: 778.89 meters
# Epoch [4/10] | Train Loss: 1143.15 meters | Test Loss: 615.22 meters
# Epoch [5/10] | Train Loss: 1063.42 meters | Test Loss: 569.52 meters
# Epoch [6/10] | Train Loss: 1038.54 meters | Test Loss: 536.44 meters
# Epoch [7/10] | Train Loss: 1029.17 meters | Test Loss: 535.99 meters
# Epoch [8/10] | Train Loss: 1023.60 meters | Test Loss: 535.23 meters
# Epoch [9/10] | Train Loss: 1018.82 meters | Test Loss: 523.30 meters
# Epoch [10/10] | Train Loss: 1016.12 meters | Test Loss: 518.84 meters
