# %%
from engine import training_loop

# %%
training_loop()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch [1/10] | Train Loss: 1143.27 meters | Test Loss: 817.90 meters
# Epoch [2/10] | Train Loss: 997.63 meters | Test Loss: 647.24 meters
# Epoch [3/10] | Train Loss: 887.00 meters | Test Loss: 576.40 meters
# Epoch [4/10] | Train Loss: 855.97 meters | Test Loss: 574.45 meters
# Epoch [5/10] | Train Loss: 843.31 meters | Test Loss: 561.04 meters
# Epoch [6/10] | Train Loss: 836.60 meters | Test Loss: 562.77 meters
# Epoch [7/10] | Train Loss: 832.05 meters | Test Loss: 566.76 meters
# Epoch [8/10] | Train Loss: 829.49 meters | Test Loss: 553.72 meters
# Epoch [9/10] | Train Loss: 826.18 meters | Test Loss: 542.83 meters
# Epoch [10/10] | Train Loss: 823.88 meters | Test Loss: 550.56 meters
