# %%
from database_conn import connect_to_azure

# %%
connect_to_azure()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 connect_to_azure()
#
# File c:\Users\yashdeshpande\Desktop\serious_projects\Serenair-Flight-Trajectory-Detection\database\database_conn.py:21, in connect_to_azure()
#      19 conn_string = get_connection_uri() # get connection string first
#      20 try:
# ---> 21     conn = psycopg.connect(conn_string) # try connecting to azure
#      22     print("Connected to azure..")
#      23     conn.close()
#
# File c:\Users\yashdeshpande\AppData\Local\Programs\Python\Python310\lib\site-packages\psycopg\connection.py:114, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     112     conn_errors.append((ex, descr))
#     113 except e._NO_TRACEBACK as ex:
# --> 114     raise ex.with_traceback(None)
#     115 else:
# ...
